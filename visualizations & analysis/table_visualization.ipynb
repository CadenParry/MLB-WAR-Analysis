# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import table

data = pd.read_csv('data/p_value_graphic.csv', sep=',')

fig, ax = plt.subplots(1, 1)

table(ax, data, loc='center')

plt.show()
